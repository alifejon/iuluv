# %%
import music21
import numpy as np

# %%
o = music21.converter.parse('TheDanceOfEternity_dr.mid')

# %%
o.show('text')

# %%
o.parts

# %%
dr_stream = music21.stream.Stream()

# %%
drum_data = []

# %%
# for n in o.parts[0].getElementsByClass(music21.note.Note):
#     print("note {} : {}".format(n, n.offset)


for n in o.parts[0].getElementsByClass(music21.chord.Chord):
    print('----')
    print("chord {} : {}".format(n, n.offset))
    print("notes {}".format(n.pitches))
    for p in n.pitches:
        print("note {} : {}".format(p.midi, n.offset))
        drum_data.append([p.midi, n.offset])
        
#     print(n.pitches[0])

# %%
len(drum_data)

# %%
for n in o.parts[0].getElementsByClass(music21.note.Note):
    print("note {} : {}".format(n.pitch.midi, n.offset))
    drum_data.append([n.pitch.midi, n.offset])

# %%
len(drum_data)

# %%
drum_data = np.array(drum_data)

# %%
drum_data = drum_data[drum_data[:, 1].argsort()]

# %%
drum_data.shape

# %%
print(drum_data[1000:1100])

# %%
full_data = music21.converter.parse('TheDanceOfEternity.mid')

# %%
full_data.show('text')
# Out:
# {0.0} <music21.stream.Part 0x10c23bf90>
#     {0.0} <music21.instrument.Instrument >
#     {0.0} <music21.tempo.MetronomeMark allegretto Quarter=106.0>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.note.Rest rest>
#     {56.0} <music21.tempo.MetronomeMark allegro moderato Quarter=128.0>
#     {84.0} <music21.tempo.MetronomeMark allegro moderato Quarter=126.0>
#     {84.0} <music21.meter.TimeSignature 7/4>
#     {84.0} <music21.note.Note G>
#     {84.5} <music21.note.Note D>
#     {85.0} <music21.note.Note G>
#     {85.5} <music21.note.Note D>
#     {86.0} <music21.note.Note F>
#     {86.5} <music21.note.Note G#>
#     {87.0} <music21.note.Note G>
#     {87.5} <music21.note.Note E->
#     {88.0} <music21.note.Note D>
#     {88.5} <music21.note.Note G>
#     {89.0} <music21.note.Note D>
#     {89.5} <music21.note.Note E->
#     {89.75} <music21.note.Note F>
#     {90.0} <music21.note.Note G>
#     {90.5} <music21.note.Note C>
#     {91.0} <music21.note.Note F>
# ...

# %%
full_data.parts
# Out:
# <music21.stream.iterator.StreamIterator for Score:0x10d9aac90 @:0>

# %%
bs_stream = music21.stream.Stream()

# %%
for p in full_data.parts:
    print(p.partName)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# Electric Bass
# Piano
# None
# None
# None
# Bass

# %%
for p in full_data.parts:
    if(p.partName == 'Electric Bass'):
        print('got bass')
        bs_stream.append(p)
# Out:
# got bass

# %%
bs_note_list = []

# %%
for element in (bs_stream.flat).getElementsByClass(music21.chord.Chord):
    print(element, element.offset, element.pitches, element._getDuration())
# Out:
# (<music21.chord.Chord D3 B2>, 410.75, (<music21.pitch.Pitch D3>, <music21.pitch.Pitch B2>), <music21.duration.Duration 1.0>)
# (<music21.chord.Chord E3 C3>, 413.75, (<music21.pitch.Pitch E3>, <music21.pitch.Pitch C3>), <music21.duration.Duration 0.5>)
# (<music21.chord.Chord E3 C3>, 414.75, (<music21.pitch.Pitch E3>, <music21.pitch.Pitch C3>), <music21.duration.Duration 1.0>)

# %%
dir(music21.note.Note())
# Out:
# ['_DOC_ATTR',
#  '_DOC_ORDER',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activeSite',
#  '_activeSiteStoredOffset',
#  '_adjacencySearch',
#  '_classListCacheDict',
#  '_classListFullyQualifiedCacheDict',
#  '_classSetCacheDict',
#  '_deepcopySubclassable',
#  '_derivation',
#  '_duration',
#  '_editorial',
#  '_getAccidental',
#  '_getActiveSite',
#  '_getColor',
#  '_getDerivation',
#  '_getDuration',
#  '_getEditorial',
#  '_getFrequency',
#  '_getLyric',
#  '_getMeasureOffset',
#  '_getMeasureOffsetOrMeterModulusOffset',
#  '_getMicrotone',
#  '_getMidi',
#  '_getName',
# ...

# %%
gt_bs_data = music21.converter.parse('TheDanceOfEternity_gt_bs.mid')

# %%
gt_stream = music21.stream.Stream()
gt_stream.append(gt_bs_data[0])

# %%
for element in (gt_stream.flat).getElementsByClass(music21.chord.Chord):
    print(element, element.offset, element.pitches, element._getDuration())
# Out:
# (<music21.chord.Chord D4 G3>, 305.75, (<music21.pitch.Pitch D4>, <music21.pitch.Pitch G3>), <music21.duration.Duration 0.25>)
# (<music21.chord.Chord D4 G3>, 306.25, (<music21.pitch.Pitch D4>, <music21.pitch.Pitch G3>), <music21.duration.Duration 0.25>)
# (<music21.chord.Chord D4 G3>, 306.75, (<music21.pitch.Pitch D4>, <music21.pitch.Pitch G3>), <music21.duration.Duration 0.25>)
# (<music21.chord.Chord D4 G3>, 307.0, (<music21.pitch.Pitch D4>, <music21.pitch.Pitch G3>), <music21.duration.Duration 0.25>)
# (<music21.chord.Chord C#4 F#3>, 307.5, (<music21.pitch.Pitch C#4>, <music21.pitch.Pitch F#3>), <music21.duration.Duration 0.25>)
# (<music21.chord.Chord E4 B3 E3>, 782.5, (<music21.pitch.Pitch E4>, <music21.pitch.Pitch B3>, <music21.pitch.Pitch E3>), <music21.duration.Duration 1.0>)
# (<music21.chord.Chord B3 E3>, 785.0, (<music21.pitch.Pitch B3>, <music21.pitch.Pitch E3>), <music21.duration.Duration 0.5>)
# ...

# %%
for element in (gt_stream.flat).getElementsByClass(music21.note.Note):
    print(element, element.offset, element.pitches, element._getDuration())
# Out:
# (<music21.note.Note G>, 84.0, [<music21.pitch.Pitch G3>], <music21.duration.Duration 0.5>)
# (<music21.note.Note D>, 84.5, [<music21.pitch.Pitch D4>], <music21.duration.Duration 0.5>)
# (<music21.note.Note G>, 85.0, [<music21.pitch.Pitch G4>], <music21.duration.Duration 0.5>)
# (<music21.note.Note D>, 85.5, [<music21.pitch.Pitch D4>], <music21.duration.Duration 0.5>)
# (<music21.note.Note F>, 86.0, [<music21.pitch.Pitch F4>], <music21.duration.Duration 0.5>)
# (<music21.note.Note G#>, 86.5, [<music21.pitch.Pitch G#4>], <music21.duration.Duration 0.5>)
# (<music21.note.Note G>, 87.0, [<music21.pitch.Pitch G4>], <music21.duration.Duration 0.5>)
# (<music21.note.Note E->, 87.5, [<music21.pitch.Pitch E-4>], <music21.duration.Duration 0.5>)
# (<music21.note.Note D>, 88.0, [<music21.pitch.Pitch D4>], <music21.duration.Duration 0.5>)
# (<music21.note.Note G>, 88.5, [<music21.pitch.Pitch G3>], <music21.duration.Duration 0.5>)
# ...
